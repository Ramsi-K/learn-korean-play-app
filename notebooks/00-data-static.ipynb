# %%
import re


def parse_strict_korean_vocab(filepath):
    words = []
    sentences = []
    word_id = 1

    with open(filepath, "r", encoding="utf-8") as f:
        lines = [line.strip() for line in f if line.strip()]

    i = 0
    while i < len(lines):
        # Skip junk lines
        if re.match(r"(?i)^page|\blingo mastery\b", lines[i]):
            i += 1
            continue

        # Vocabulary line
        line = lines[i]
        match = re.match(
            r"^(\d+)[–\-\.]?\s+([가-힣]+)\s*/\s*([\w\-]+)\s*\[([a-zA-Z\. ]+)\]\s+(.+)",
            line,
        )
        if not match:
            i += 1
            continue

        _, word, romanization, pos_raw, meaning_text = match.groups()
        pos = pos_raw.strip().lower().rstrip(".")
        meanings = [m.strip() for m in meaning_text.split(",")]

        # Example sentences
        example_kr = lines[i + 1] if i + 1 < len(lines) else ""
        example_en = lines[i + 2] if i + 2 < len(lines) else ""

        if pos == "n":
            pos == "noun"
        elif pos == "num":
            pos = "number"
        elif pos == "pron":
            pos = "pronoun"
        elif pos == "v":
            pos = "verb"
        elif pos == "a":
            pos = "adjective"
        elif pos == "adv":
            pos = "adverb"
        elif pos == "determiner":
            pos = "determiner"
        elif pos == "assistant v":
            pos = "assistant verb"
        elif pos == "adj":
            pos = "adjective"
        elif pos == "determine":
            pos = "determiner"
        elif pos == "p":
            pos = "pronoun"

        for meaning in meanings:
            words.append(
                {
                    "id": word_id,
                    "word": word,
                    "romanization": romanization,
                    "pos": pos,
                    "meaning": meaning,
                }
            )

            if example_kr and example_en:
                sentences.append(
                    {
                        "word_id": word_id,
                        "example_kr": example_kr,
                        "example_en": example_en,
                    }
                )

            word_id += 1

        i += 3  # move to next vocab block

    return words, sentences

# %%
words, sentences = parse_strict_korean_vocab(
    "txt_path=../../../assets/data/raw/words/2000 Most Common Korean Words i - Lingo Mastery.txt"
)
len(words)
# Out:
# 5394

# %%
len(sentences)
# Out:
# 5394

# %%
unique_pos = {word["pos"] for word in words}
unique_pos
# Out:
# {'',
#  'adjective',
#  'adverb',
#  'assistant verb',
#  'counter',
#  'determiner',
#  'interjection',
#  'n',
#  'number',
#  'pronoun',
#  's',
#  'verb'}

# %%
len(words)
# Out:
# 5394

# %%
words[:50]
# Out:
# [{'id': 1,
#   'word': '것',
#   'romanization': 'geot',
#   'pos': 'n',
#   'meaning': 'a thing'},
#  {'id': 2,
#   'word': '것',
#   'romanization': 'geot',
#   'pos': 'n',
#   'meaning': 'an object'},
#  {'id': 3,
#   'word': '하다',
#   'romanization': 'hada',
#   'pos': 'v',
#   'meaning': 'to do'},
#  {'id': 4,
#   'word': '하다',
#   'romanization': 'hada',
#   'pos': 'v',
#   'meaning': 'to make'},
#  {'id': 5,
#   'word': '있다',
#   'romanization': 'itda',
#   'pos': 'v',
#   'meaning': 'to be (in a place)'},
#  {'id': 6,
#   'word': '있다',
#   'romanization': 'itda',
#   'pos': 'v',
#   'meaning': 'exist'},
#  {'id': 7,
#   'word': '있다',
#   'romanization': 'itda',
#   'pos': 'v',
#   'meaning': 'have'},
#  {'id': 8,
#   'word': '있다',
#   'romanization': 'itda',
#   'pos': 'assistant v',
#   'meaning': 'to be (in a state)'},
#  {'id': 9,
#   'word': '되다',
#   'romanization': 'doeda',
#   'pos': 'v',
#   'meaning': 'to become'},
#  {'id': 10, 'word': '수', 'romanization': 'su', 'pos': 'n', 'meaning': 'way'},
#  {'id': 11, 'word': '수', 'romanization': 'su', 'pos': 'n', 'meaning': 'means'},
#  {'id': 12,
#   'word': '수',
#   'romanization': 'su',
#   'pos': 'n',
#   'meaning': 'possibility'},
#  {'id': 13,
#   'word': '같다',
#   'romanization': 'gatda',
#   'pos': 'a',
#   'meaning': '(to be) the same'},
#  {'id': 14,
#   'word': '같다',
#   'romanization': 'gatda',
#   'pos': 'a',
#   'meaning': '(to be) like or similar'},
#  {'id': 15,
#   'word': '같다',
#   'romanization': 'gatda',
#   'pos': 'a',
#   'meaning': '(to be) probably so'},
#  {'id': 16, 'word': '나', 'romanization': 'na', 'pos': 'n', 'meaning': 'I'},
#  {'id': 17,
#   'word': '그',
#   'romanization': 'geu',
#   'pos': 'pron',
#   'meaning': 'he'},
#  {'id': 18,
#   'word': '아니다',
#   'romanization': 'anida',
#   'pos': 'a',
#   'meaning': 'not be'},
#  {'id': 19,
#   'word': '보다',
#   'romanization': 'boda',
#   'pos': 'v',
#   'meaning': 'to see'},
#  {'id': 20,
#   'word': '보다',
#   'romanization': 'boda',
#   'pos': 'v',
#   'meaning': 'look at'},
#  {'id': 21,
#   'word': '보다',
#   'romanization': 'boda',
#   'pos': 'v',
#   'meaning': 'watch'},
#  {'id': 22,
#   'word': '보다',
#   'romanization': 'boda',
#   'pos': 'v',
#   'meaning': 'read'},
#  {'id': 23,
#   'word': '등',
#   'romanization': 'deung',
#   'pos': 'n',
#   'meaning': 'back'},
#  {'id': 24,
#   'word': '때',
#   'romanization': 'ttae',
#   'pos': 'n',
#   'meaning': 'time'},
#  {'id': 25,
#   'word': '때',
#   'romanization': 'ttae',
#   'pos': 'n',
#   'meaning': 'an occasion'},
#  {'id': 26,
#   'word': '때',
#   'romanization': 'ttae',
#   'pos': 'n',
#   'meaning': 'the time when'},
#  {'id': 27,
#   'word': '거',
#   'romanization': 'geo',
#   'pos': 'n',
#   'meaning': 'thing'},
#  {'id': 28,
#   'word': '거',
#   'romanization': 'geo',
#   'pos': 'n',
#   'meaning': 'that which'},
#  {'id': 29, 'word': '거', 'romanization': 'geo', 'pos': 'n', 'meaning': 'what'},
#  {'id': 30,
#   'word': '가다',
#   'romanization': 'gada',
#   'pos': 'v',
#   'meaning': 'to go'},
#  {'id': 31,
#   'word': '주다',
#   'romanization': 'juda',
#   'pos': 'v',
#   'meaning': 'to give'},
#  {'id': 32,
#   'word': '대하다',
#   'romanization': 'daehada',
#   'pos': 'v',
#   'meaning': 'to respond to'},
#  {'id': 33,
#   'word': '년',
#   'romanization': 'nyeon',
#   'pos': 'n',
#   'meaning': 'year'},
#  {'id': 34, 'word': '한', 'romanization': 'han', 'pos': 'n', 'meaning': 'one'},
#  {'id': 35,
#   'word': '한',
#   'romanization': 'han',
#   'pos': 'n',
#   'meaning': '(before a numeral) about'},
#  {'id': 36,
#   'word': '한',
#   'romanization': 'han',
#   'pos': 'n',
#   'meaning': 'around'},
#  {'id': 37, 'word': '말', 'romanization': 'mal', 'pos': 'n', 'meaning': 'word'},
#  {'id': 38,
#   'word': '말',
#   'romanization': 'mal',
#   'pos': 'n',
#   'meaning': 'speech'},
#  {'id': 39, 'word': '일', 'romanization': 'il', 'pos': 'n', 'meaning': 'work'},
#  {'id': 40, 'word': '일', 'romanization': 'il', 'pos': 'n', 'meaning': 'job'},
#  {'id': 41,
#   'word': '일',
#   'romanization': 'il',
#   'pos': 'n',
#   'meaning': 'business'},
#  {'id': 42,
#   'word': '일',
#   'romanization': 'il',
#   'pos': 'n',
#   'meaning': 'matter'},
#  {'id': 43,
#   'word': '이',
#   'romanization': 'i',
#   'pos': 'pron',
#   'meaning': 'this'},
#  {'id': 44,
#   'word': '때문에',
#   'romanization': 'ttaemune',
#   'pos': 'n',
#   'meaning': 'Because of'},
#  {'id': 45,
#   'word': '때문에',
#   'romanization': 'ttaemune',
#   'pos': 'n',
#   'meaning': 'Because'},
#  {'id': 46,
#   'word': '말하다',
#   'romanization': 'malhada',
#   'pos': 'v',
#   'meaning': 'to speak'},
#  {'id': 47,
#   'word': '말하다',
#   'romanization': 'malhada',
#   'pos': 'v',
#   'meaning': 'to talk'},
#  {'id': 48,
#   'word': '말하다',
#   'romanization': 'malhada',
#   'pos': 'v',
#   'meaning': 'to say'},
#  {'id': 49,
#   'word': '위하다',
#   'romanization': 'wihada',
#   'pos': 'v',
#   'meaning': 'to help or benefit'},
#  {'id': 50,
#   'word': '위하다',
#   'romanization': 'wihada',
#   'pos': 'v',
#   'meaning': 'to do for the sake of'}]

# %%
import json

# Save words to a JSON file
with open(
    "../assets/data/processed/korean_words_2000.json", "w", encoding="utf-8"
) as words_file:
    json.dump(words, words_file, ensure_ascii=False, indent=4)

# Save sentences to a JSON file
with open(
    "../assets/data/processed/korean_sentences_2000.json",
    "w",
    encoding="utf-8",
) as sentences_file:
    json.dump(sentences, sentences_file, ensure_ascii=False, indent=4)
